# %% [markdown]
# # Day 13 Assignments: ML Interview Metrics
#
# Complete each task and replace the TODOs. Each task includes `assert` checks to verify your result.

# %% [markdown]
# ## NumPy Task: Confusion matrix + F1
# You are given binary predictions and labels.
#
# 1) Compute `tp`, `fp`, `fn`, `tn`
# 2) Compute precision, recall, and F1

# %%
import numpy as np

y_true = np.array([1, 0, 1, 1, 0, 0, 1, 0, 1, 0])
y_pred = np.array([1, 0, 0, 1, 0, 1, 1, 0, 0, 0])

# TODO: compute tp, fp, fn, tn
tp = None
fp = None
fn = None
tn = None

# TODO: compute precision, recall, f1 (floats)
precision = None
recall = None
f1 = None

assert (tp, fp, fn, tn) == (3, 1, 2, 4), "Confusion matrix counts are incorrect."
assert np.isclose(precision, 0.75), "Precision should be 0.75."
assert np.isclose(recall, 0.6), "Recall should be 0.6."
assert np.isclose(f1, 2/3), "F1 should be 0.666666..."

# %% [markdown]
# ## Pandas Task: Precision/recall at a threshold
# Interview question: how does the decision threshold affect metrics?
#
# 1) Create `y_pred` using threshold 0.5
# 2) Compute precision and recall

# %%
import pandas as pd

df = pd.DataFrame({
    "y_true": [1, 0, 1, 0, 1, 0, 1, 0],
    "y_score": [0.9, 0.4, 0.6, 0.3, 0.55, 0.8, 0.2, 0.1],
})

threshold = 0.5

# TODO: add y_pred based on threshold
# TODO: compute precision and recall
y_pred = None
precision = None
recall = None

assert y_pred is not None, "y_pred is None."
assert list(y_pred) == [1, 0, 1, 0, 1, 1, 0, 0], "y_pred values are incorrect."
assert abs(precision - 0.75) < 1e-9, "Precision should be 0.75."
assert abs(recall - 0.75) < 1e-9, "Recall should be 0.75."
