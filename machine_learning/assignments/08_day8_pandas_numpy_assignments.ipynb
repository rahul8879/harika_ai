# %% [markdown]
# # Day 8 Assignments: NumPy + Pandas
#
# Complete each task and replace the TODOs. Each task includes `assert` checks to verify your result.

# %% [markdown]
# ## NumPy Task: Reshape and reduce
# You are given 12 monthly values.
#
# 1) Reshape into 3x4 (quarters x months)
# 2) Compute quarterly sums
# 3) Find the quarter with the maximum sum (0-based index)

# %%
import numpy as np

months = np.array([5, 7, 6, 8, 9, 7, 6, 5, 8, 10, 9, 7], dtype=float)

# TODO: reshape to 3x4
q = None

# TODO: compute quarterly sums
q_sums = None

# TODO: find index of max quarter
max_q = None

expected_q = months.reshape(3, 4)
expected_sums = expected_q.sum(axis=1)
expected_max = int(expected_sums.argmax())

assert q is not None, "q is None."
assert q_sums is not None, "q_sums is None."
assert max_q is not None, "max_q is None."
assert np.array_equal(q, expected_q), f"Expected {expected_q}, got {q}"
assert np.array_equal(q_sums, expected_sums), f"Expected {expected_sums}, got {q_sums}"
assert max_q == expected_max, f"Expected {expected_max}, got {max_q}"

# %% [markdown]
# ## Pandas Task: Rename, compute, and sort
# You are given salary data.
#
# 1) Rename column `dept` to `department`
# 2) Compute yearly cost per row: `monthly * 12`
# 3) Return total yearly cost per department sorted descending

# %%
import pandas as pd

salary = pd.DataFrame({
    "dept": ["Eng", "HR", "Eng", "Sales"],
    "monthly": [5000, 3000, 5500, 4000],
})

# TODO: rename dept to department
salary_clean = None

# TODO: compute yearly cost and group by department
cost_by_department = None

expected = pd.Series({"Eng": 126000, "Sales": 48000, "HR": 36000})

assert salary_clean is not None, "salary_clean is None."
assert cost_by_department is not None, "cost_by_department is None."
assert cost_by_department.equals(expected), f"Expected {expected}, got {cost_by_department}"
